# %% [markdown]
# <font face="times new roman" size="3" color="white">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="white"> Отчет по лабораторной работе №12 </center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«GIT»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="white"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="white">       БИК2506 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="white"> Швыряев Олег Павлович</p>
#   <p  align="right"> <font face="times new roman" size="3" color="white"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="white"> Старший преподаватель кафедры ТиЗВ Егоров Дмитрий Аркадьевич </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="white"> Москва, 2025 г. </p>
#
#   <hr>

# %% [markdown]
# Цель: Ознакомиться с основами GIT, создать репозитории, добавить в них файлы и выгрузить это все на GITHUB, а также выгрузить на него ранее созданный сайт

# %% [markdown]
# 1. Установим GIT

# %% [markdown]
# 2. Создаем репрезиторий:
# git init

# %% [markdown]
# 3. Создадим файл в папке, добавим файл в репрезиторий:
#
# ![Снимок экрана 2025-11-27 173717.png](data:image/png;base64,...)

# %% [markdown]
# 4. Делаем коммит под названием "Init":
#
# ![Снимок экрана 2025-11-27 173957.png](data:image/png;base64,...)

# %% [markdown]
# 5. Создаем ветку и переключаемся на нее:
#
#
# ![Снимок экрана 2025-11-27 174105.png](data:image/png;base64,...)

# %% [markdown]
# 6. Обновляем отчет и сохраняем изменения:
#
# ![Снимок экрана 2025-11-27 174217.png](data:image/png;base64,...)

# %% [markdown]
# 7. Сливаем в основную ветку:
#
# ![Снимок экрана 2025-11-27 174421.png](data:image/png;base64,...)

# %% [markdown]
# 8. Создали пустой репозиторий на GITHUB и залили на него содержимое локального репозитория:
#
# ![Снимок экрана 2025-11-27 175449.png](data:image/png;base64,...)

# %% [markdown]
# 9. Разместили ранне созданный статический сайт:
#
# ![Снимок экрана 2025-11-27 180142.png](data:image/png;base64,...)
